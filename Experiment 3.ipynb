# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahra2351373/Image-Processing-Final-Project/blob/Master/Experiment%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Libraries
# Firstly, necessary libraries including OpenCV for image processing tasks, and convolution layer and max pool for implementing contracting path must be imported. An input layer is needed for feeding images to the network. Also transposed and concatenation layers are critical for implementing expansive and connection paths respectively.PIL library is used for image processing tasks and NumPy is needed for computing purposes. Matplotlib is critical for sowing graphs and images and ImageDataGenerator of the Keras is needed for the data augmentation task.

# %%
import cv2
import glob
import os
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Input 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Cropping2D
from tensorflow.keras.layers import UpSampling2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import concatenate
from tensorflow.keras.models import Model
from PIL import Image
from PIL import ImageSequence
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow.keras.backend as K
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# #Defining Image size
# Image size and channels must be defined and 1 relates to the grayscale image.

# %%
num_classes = 1
image_height=256
image_width=256
image_size=(256,256)

# %% [markdown]
# #Mounting Google Drive
# This allows the colab to access folders located in google drive. Then I need to unzip our zip files including image data and image mask to use them in my deep neural network.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir("/content/drive/MyDrive/")
os.listdir()
# Out:
# ['tr_mask.nii.gz',
#  'val_im.nii.gz',
#  'Colab Notebooks',
#  'test-volume',
#  'train-labels',
#  'train-volume',
#  'Dataset',
#  'test-volume.zip',
#  'train-labels.zip',
#  'train-volume.zip',
#  'images',
#  'tr_im.nii.gz',
#  'blkwht.jpg',
#  'Dataset.zip',
#  'kaggle.json',
#  'kaggle']

# %%
# !unzip -uq "/content/drive/MyDrive/train-volume.zip" -d "/content/drive/MyDrive/Dataset"
# !unzip -uq "/content/drive/MyDrive/train-labels.zip" -d "/content/drive/MyDrive/Dataset"
# !unzip -uq "/content/drive/MyDrive/test-volume.zip" -d "/content/drive/MyDrive/Dataset"

# %%
labels = glob.glob('/content/drive/MyDrive/train-labels/*.jpg')
datas = glob.glob('/content/drive/MyDrive/train-volume/*.jpg')

# %%
labels
# Out:
# ['/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-22.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-21.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-16.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-15.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-27.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-12.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-17.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-1.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-9.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-26.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-19.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-7.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-25.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-10.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-29.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-14.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-6.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-18.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-13.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-2.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-0.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-8.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-4.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-24.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-23.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-20.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-3.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-5.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-28.jpg',
#  '/content/drive/MyDrive/train-labels/762ea16c413449c49ac2c2061987a9f6FPQDADvZRhCjXLMm-11.jpg']

# %%
datas
# Out:
# ['/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-22.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-19.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-25.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-2.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-10.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-12.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-4.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-21.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-6.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-23.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-27.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-9.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-20.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-28.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-29.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-15.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-13.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-8.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-11.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-14.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-24.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-26.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-16.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-7.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-18.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-5.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-0.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-1.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-17.jpg',
#  '/content/drive/MyDrive/train-volume/69f8ef7180b24fb2cd2cd352e035aa52bkiUFPPWFzrkvMy9-3.jpg']

# %% [markdown]
# #Data Preparation
# I have to map image data to image labels for training my model. For this task, I have to read image by Image.open(images) and I want to make sure that the size of the image is 256x256 by resize(image_size), I have to do this for masks too. An array is created by image and labels using np.array() as I have to work with arrays, not images for training my deep neural network.

# %%
images = []
masks = []
for image, mask in zip(datas, labels):
    
    images.append(np.array(Image.open(image).resize(image_size)))
    masks.append(np.array(Image.open(mask).resize(image_size)))    
images = np.array(images)
masks = np.array(masks)
print(images.shape, masks.shape)
# Out:
# (30, 256, 256) (30, 256, 256)

# %% [markdown]
# As the number of channels is important for deep neural networks I reshaped my data using reshape(data_images.shape + (1,)). I should mention that I also could use NumPy.expand_dims instead of reshape(data_images.shape + (1,)) for my task.Then I divided my image and labels into 255(maximum number of pixels for an image= 2^8 - 1) to prevent huge computations in convolutions and loss information, that is why it is better that input numbers are normalized and their values are between 0 and 1.

# %%
images = images.reshape(images.shape + (1,))
masks = masks.reshape(masks.shape + (1,))

images = images/255.0
masks = masks/255.0

# %% [markdown]
# #Dividing Data
# I used the scikit-learn library for train-test-split to use 30% of data for validation as my dataset does not have validation images and I have to use a part of my data for validation, and 70% of my data for training my model. The random state is a parameter that is initialized to 42 in most of the deep neural networks but I chose it 0 and did not change it as I do not want to initialize random to be impactful on choosing parameters and hyperparameters of my model in each training process.

# %%
train_data, val_data, train_label, val_label = train_test_split(
    images, masks,test_size=0.3, random_state=0)

print("train_data: ", train_data.shape)
print("train_label: ", train_label.shape)
print("val_data: ", val_data.shape)
print("val_label: ", val_label.shape)
# Out:
# train_data:  (21, 256, 256, 1)
# train_label:  (21, 256, 256, 1)
# val_data:  (9, 256, 256, 1)
# val_label:  (9, 256, 256, 1)

# %% [markdown]
# #Data Augmentation
# Data augmentation is the cheapest way to train more data for my deep neural network model. I defined appropriate parameters for data augmentation task with random seed=42, as I mentioned before it is important that random seed be constant. Keras does data augmentation using ImageDataGenerator with by default parameters and I can change these parameters in the next code block. I should mention that generally validation data is not augmented and I did not augment my validation data but I had to define in my function to avoid errors.

# %%
def data_augmentation(train_data, trian_label, val_data= None, val_label= None, batch_size=32,
                 seed=42, datagen_args= dict(rotation_range=15., width_shift_range=0.05,
                                            height_shift_range=0.05, shear_range=0.09,
                                            zoom_range=0.02, horizontal_flip=True, 
                                            vertical_flip=True, fill_mode='constant')):
    
    train_data_datagen = ImageDataGenerator(**datagen_args)
    train_label_datagen = ImageDataGenerator(**datagen_args)
    
    train_data_datagen.fit(train_data, augment=True, seed=seed)
    train_label_datagen.fit(train_label, augment=True, seed=seed)
    
    train_data_augmented = train_data_datagen.flow(train_data, batch_size=batch_size,
                                                  shuffle=True, seed=seed)
    train_label_augmented = train_label_datagen.flow(train_label, batch_size=batch_size,
                                                    shuffle=True, seed=seed)
    
    train_generator = zip(train_data_augmented, train_label_augmented)
    
    if (val_data!= None) and (val_label!= None):
        valid_data_datagen = ImageDataGenerator(**datagen_args)
        valid_label_datagen = ImageDataGenerator(**datagen_args)

        valid_data_datagen.fit(valid_data, augment=True, seed=seed)
        valid_label_datagen.fit(valid_label, augment=True, seed=seed)

        valid_data_augmented = valid_data_datagen.flow(valid_data, batch_size=batch_size,
                                                      shuffle=True, seed=seed)
        valid_label_augmented = valid_label_datagen.flow(valid_label, batch_size=batch_size,
                                                        shuffle=True, seed=seed)
        
        valid_generator = zip(valid_data_augmented, valid_label_augmented)
        
        return train_generator, valid_generator
    
    else:
        return train_generator

# %%
train_gen = data_augmentation(
    train_data, train_label, batch_size=2,
    datagen_args= dict(
        rotation_range=15.,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=50,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='constant'
    ))

# %% [markdown]
# #Building Model
# I defined my model using defining contracting path function which does convolution but I did not apply max-pooling in this part. I implemented each step using my defined function. The difference between my implementation and the original U-Net implementation is in the original paper the images are in the size of 572x572 but I resized to 256x256 to decrease computations.The activation function based on the original U-Net paper is relu but I used selu and as I do not want to apply padding that is why the padding is the same here. The U-Net is not a sequential model and it contains the skip connections path, that is why I have to use concatenation. Dropout layer is necessary to avoid overfitting and batch normalization is critical too to make sure that all values are in 0 to 1. As the U-Net has 4 stages of convolutions that is why the number of layers is 4 and the filter size starts with 16 and becomes twice. Then I had to use transpose convolution for the expansive path and I had to repeat it 4 times as U-Net has 4 stages of this.

# %%
def contract_conv(input_x, filters, act='selu', pad='same'):
    c = Conv2D(filters,(3,3),activation=act, padding=pad)(input_x)
    c = BatchNormalization()(c)
    c = Dropout(0.3)(c)
    c = Conv2D(filters,(3,3),activation='selu', padding=pad)(c)
    c = BatchNormalization()(c)
    return c

# %%
filters, num_layers= 16, 4
input_layer = Input((256, 256, 1))

# %%
unet_layers = input_layer
conv_layers = []
for l in range(num_layers):
      unet_layers = contract_conv(unet_layers, filters=filters)
      print(unet_layers)
      conv_layers.append(unet_layers)
      unet_layers = MaxPool2D((2,2))(unet_layers)
      filters *= 2
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 16), dtype=tf.float32, name=None), name='batch_normalization_1/FusedBatchNormV3:0', description="created by layer 'batch_normalization_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 32), dtype=tf.float32, name=None), name='batch_normalization_3/FusedBatchNormV3:0', description="created by layer 'batch_normalization_3'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 64), dtype=tf.float32, name=None), name='batch_normalization_5/FusedBatchNormV3:0', description="created by layer 'batch_normalization_5'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 128), dtype=tf.float32, name=None), name='batch_normalization_7/FusedBatchNormV3:0', description="created by layer 'batch_normalization_7'")

# %%
unet_layers = contract_conv(input_x=unet_layers, filters=filters,pad='same')
print(unet_layers)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 256), dtype=tf.float32, name=None), name='batch_normalization_9/FusedBatchNormV3:0', description="created by layer 'batch_normalization_9'")

# %%
for conv in reversed(conv_layers):
  filters //= 2
  unet_layers = Conv2DTranspose(filters,(2, 2),strides=(2, 2), padding='same')(unet_layers)
  print("====================")
  print(unet_layers)
  print("====================")
  print(conv)
  print("====================")
  unet_layers = concatenate([unet_layers,conv])
  unet_layers = contract_conv(unet_layers, filters)
output_layer = Conv2D(num_classes, (1,1), activation='sigmoid')(unet_layers)
# Out:
# ====================
# KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 128), dtype=tf.float32, name=None), name='conv2d_transpose/BiasAdd:0', description="created by layer 'conv2d_transpose'")
# ====================
# KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 128), dtype=tf.float32, name=None), name='batch_normalization_7/FusedBatchNormV3:0', description="created by layer 'batch_normalization_7'")
# ====================
# ====================
# KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 64), dtype=tf.float32, name=None), name='conv2d_transpose_1/BiasAdd:0', description="created by layer 'conv2d_transpose_1'")
# ====================
# KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 64), dtype=tf.float32, name=None), name='batch_normalization_5/FusedBatchNormV3:0', description="created by layer 'batch_normalization_5'")
# ====================
# ====================
# KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 32), dtype=tf.float32, name=None), name='conv2d_transpose_2/BiasAdd:0', description="created by layer 'conv2d_transpose_2'")
# ====================
# KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 32), dtype=tf.float32, name=None), name='batch_normalization_3/FusedBatchNormV3:0', description="created by layer 'batch_normalization_3'")
# ====================
# ====================
# KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 16), dtype=tf.float32, name=None), name='conv2d_transpose_3/BiasAdd:0', description="created by layer 'conv2d_transpose_3'")
# ====================
# KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 16), dtype=tf.float32, name=None), name='batch_normalization_1/FusedBatchNormV3:0', description="created by layer 'batch_normalization_1'")
# ====================

# %%
u_net= Model(inputs=input_layer, outputs=output_layer)
u_net.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 160         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256, 256, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 2320        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128, 128, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 128)  147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 128)  131200      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 256)  0           conv2d_transpose[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 128)  147584      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 64)   32832       batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 64)   36928       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 32) 8224        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 128, 32) 128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 128, 128, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 32) 9248        dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 128, 32) 128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 16) 2064        batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 32) 0           conv2d_transpose_3[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 16) 4624        concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 256, 256, 16) 64          conv2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 256, 256, 16) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 16) 2320        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256, 256, 16) 64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  17          batch_normalization_17[0][0]
# ==================================================================================================
# Total params: 1,946,705
# Trainable params: 1,943,761
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %% [markdown]
# #Metrics
# IoU is one of the metrics for evaluating deep neural network models. Although other metrics can be used including jaccard_coef, threshold_binarize, and threshold_binarize, I used IoU as the original U-Net paper was based on it.

# %%
def iou(y_true, y_pred, smooth=1.):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    res = (intersection + smooth) / (K.sum(y_true) + K.sum(y_pred) - intersection + smooth)
    
    return res

def iou_thresholded(y_true, y_pred, threshold=0.5, smooth=1.):
    y_pred = threshold_binarize(y_pred, threshold)
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    res = (intersection + smooth) / (K.sum(y_true) + K.sum(y_pred) - intersection + smooth)
    
    return res

def threshold_binarize(x, threshold=0.5):
    ge = tf.greater_equal(x, tf.constant(threshold))
    y = tf.where(ge, x=tf.ones_like(x), y=tf.zeros_like(x))
    return y

# %% [markdown]
# #Compiling Model
# I compiled my model using SGD optimizer with the highest momentum and learning rate of 0.01 and binary-crossentropy loss function.

# %%
u_net.compile(
    optimizer=SGD(lr=0.01,momentum=0.99),
    loss='binary_crossentropy',
    metrics=[iou, iou_thresholded]
)

# %%
hist = u_net.fit_generator(train_gen, steps_per_epoch=100,\
                epochs=20, validation_data=(val_data, val_label))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/20
# 100/100 [==============================] - 41s 55ms/step - loss: 0.5920 - iou: 0.5631 - iou_thresholded: 0.6612 - val_loss: 0.5853 - val_iou: 0.7078 - val_iou_thresholded: 0.7765
# Epoch 2/20
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4625 - iou: 0.6329 - iou_thresholded: 0.7697 - val_loss: 0.5634 - val_iou: 0.6857 - val_iou_thresholded: 0.7747
# Epoch 3/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4731 - iou: 0.6307 - iou_thresholded: 0.7740 - val_loss: 0.5397 - val_iou: 0.6311 - val_iou_thresholded: 0.7761
# Epoch 4/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4606 - iou: 0.6393 - iou_thresholded: 0.7795 - val_loss: 0.5427 - val_iou: 0.6037 - val_iou_thresholded: 0.7762
# Epoch 5/20
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4730 - iou: 0.6282 - iou_thresholded: 0.7751 - val_loss: 0.5366 - val_iou: 0.6451 - val_iou_thresholded: 0.7764
# Epoch 6/20
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4592 - iou: 0.6296 - iou_thresholded: 0.7742 - val_loss: 0.5436 - val_iou: 0.6634 - val_iou_thresholded: 0.7765
# Epoch 7/20
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4565 - iou: 0.6447 - iou_thresholded: 0.7778 - val_loss: 0.5330 - val_iou: 0.6281 - val_iou_thresholded: 0.7765
# Epoch 8/20
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4544 - iou: 0.6376 - iou_thresholded: 0.7784 - val_loss: 0.5396 - val_iou: 0.6317 - val_iou_thresholded: 0.7764
# Epoch 9/20
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4645 - iou: 0.6344 - iou_thresholded: 0.7749 - val_loss: 0.5380 - val_iou: 0.6600 - val_iou_thresholded: 0.7764
# Epoch 10/20
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4589 - iou: 0.6400 - iou_thresholded: 0.7773 - val_loss: 0.5323 - val_iou: 0.6456 - val_iou_thresholded: 0.7763
# Epoch 11/20
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4571 - iou: 0.6402 - iou_thresholded: 0.7777 - val_loss: 0.5368 - val_iou: 0.6445 - val_iou_thresholded: 0.7764
# Epoch 12/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4492 - iou: 0.6438 - iou_thresholded: 0.7786 - val_loss: 0.5380 - val_iou: 0.6562 - val_iou_thresholded: 0.7762
# Epoch 13/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4586 - iou: 0.6342 - iou_thresholded: 0.7771 - val_loss: 0.5408 - val_iou: 0.6636 - val_iou_thresholded: 0.7764
# Epoch 14/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4603 - iou: 0.6514 - iou_thresholded: 0.7779 - val_loss: 0.5347 - val_iou: 0.6502 - val_iou_thresholded: 0.7765
# Epoch 15/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4525 - iou: 0.6328 - iou_thresholded: 0.7770 - val_loss: 0.5309 - val_iou: 0.6427 - val_iou_thresholded: 0.7764
# Epoch 16/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4564 - iou: 0.6372 - iou_thresholded: 0.7774 - val_loss: 0.5324 - val_iou: 0.6565 - val_iou_thresholded: 0.7765
# Epoch 17/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4622 - iou: 0.6346 - iou_thresholded: 0.7759 - val_loss: 0.5312 - val_iou: 0.6456 - val_iou_thresholded: 0.7764
# Epoch 18/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4537 - iou: 0.6468 - iou_thresholded: 0.7787 - val_loss: 0.5454 - val_iou: 0.6714 - val_iou_thresholded: 0.7765
# Epoch 19/20
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4500 - iou: 0.6439 - iou_thresholded: 0.7782 - val_loss: 0.5297 - val_iou: 0.6373 - val_iou_thresholded: 0.7765
# Epoch 20/20
# 100/100 [==============================] - 3s 30ms/step - loss: 0.4597 - iou: 0.6325 - iou_thresholded: 0.7782 - val_loss: 0.5401 - val_iou: 0.6725 - val_iou_thresholded: 0.7765

# %% [markdown]
# #Results
# I used matplotlib for showing my results.

# %%
res = u_net.predict(train_data[3].reshape(1, 256, 256,1))
res = (res >0.75)

# %%
plt.imshow(np.reshape(res[0]*255, image_size), cmap='gray')

# %%
plt.imshow(np.reshape(train_label[0]*255, image_size), cmap='gray')

# %%
plt.imshow(np.reshape(train_data[0]*255, image_size), cmap='gray')
